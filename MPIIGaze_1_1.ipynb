# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
# !tar -xvf  /content/Drive/MyDrive/MPIIGaze.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# MPIIGaze/Data/Original/p06/day01/0292.jpg
# MPIIGaze/Data/Original/p06/day01/0244.jpg
# MPIIGaze/Data/Original/p06/day01/0182.jpg
# MPIIGaze/Data/Original/p06/day01/0153.jpg
# MPIIGaze/Data/Original/p06/day01/0295.jpg
# MPIIGaze/Data/Original/p06/day01/0238.jpg
# MPIIGaze/Data/Original/p06/day01/0077.jpg
# MPIIGaze/Data/Original/p06/day01/0166.jpg
# MPIIGaze/Data/Original/p06/day01/0271.jpg
# MPIIGaze/Data/Original/p06/day01/0329.jpg
# MPIIGaze/Data/Original/p06/day01/0093.jpg
# MPIIGaze/Data/Original/p06/day01/0042.jpg
# MPIIGaze/Data/Original/p06/day01/0094.jpg
# MPIIGaze/Data/Original/p06/day01/0045.jpg
# MPIIGaze/Data/Original/p06/day01/0161.jpg
# MPIIGaze/Data/Original/p06/day01/0276.jpg
# MPIIGaze/Data/Original/p06/day01/0039.jpg
# MPIIGaze/Data/Original/p06/day01/0113.jpg
# MPIIGaze/Data/Original/p06/day01/0204.jpg
# MPIIGaze/Data/Original/p06/day01/0278.jpg
# MPIIGaze/Data/Original/p06/day01/0320.jpg
# ...

# %% [markdown]
# # New section

# %%
# !git clone https://github.com/NVlabs/few_shot_gaze.git
# Out:
# Cloning into 'few_shot_gaze'...
# remote: Enumerating objects: 248, done.
# remote: Total 248 (delta 0), reused 0 (delta 0), pack-reused 248
# Receiving objects: 100% (248/248), 37.78 MiB | 23.75 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
# %cd /content/few_shot_gaze
# Out:
# /content/few_shot_gaze

# %%
# !git submodule update --init --recursive
# Out:
# Submodule 'demo/ext/HRNet-Facial-Landmark-Detection' (https://github.com/HRNet/HRNet-Facial-Landmark-Detection) registered for path 'demo/ext/HRNet-Facial-Landmark-Detection'
# Submodule 'demo/ext/eos' (https://github.com/patrikhuber/eos) registered for path 'demo/ext/eos'
# Submodule 'preprocess' (https://github.com/swook/faze_preprocess) registered for path 'preprocess'
# Cloning into '/content/few_shot_gaze/demo/ext/HRNet-Facial-Landmark-Detection'...
# Cloning into '/content/few_shot_gaze/demo/ext/eos'...
# Cloning into '/content/few_shot_gaze/preprocess'...
# Submodule path 'demo/ext/HRNet-Facial-Landmark-Detection': checked out 'acdec19ebb631d0116574f85b367de075ef789f3'
# Submodule path 'demo/ext/eos': checked out '9ac31018893bc1f3adda7382725c383e1560cfac'
# Submodule '3rdparty/cereal' (https://github.com/USCiLab/cereal.git) registered for path 'demo/ext/eos/3rdparty/cereal'
# ...

# %%
# %cd /content/few_shot_gaze/preprocess
# Out:
# /content/few_shot_gaze/preprocess

# %%
# !bash ./grab_prerequisites.bash
# Out:
# ...
# --2021-07-31 16:54:46--  https://ait.ethz.ch/projects/2019/faze/downloads/preprocessing/MPIIFaceGaze_supplementary.h5
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12846478 (12M) [text/plain]
# Saving to: ‘MPIIFaceGaze_supplementary.h5’
#
# MPIIFaceGaze_supple 100%[===================>]  12.25M  5.73MB/s    in 2.1s
#
# 2021-07-31 16:54:49 (5.73 MB/s) - ‘MPIIFaceGaze_supplementary.h5’ saved [12846478/12846478]
#
# --2021-07-31 16:54:49--  https://ait.ethz.ch/projects/2019/faze/downloads/preprocessing/GazeCapture_supplementary.h5
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 709970152 (677M) [text/plain]
# Saving to: ‘GazeCapture_supplementary.h5’
#
# ...

# %%
# !mkdir /content/few_shot_gaze/demo/ext/HRNet-Facial-Landmark-Detection/hrnetv2_pretrained
# !cp /content/Drive/MyDrive/HR18-WFLW.pth /content/few_shot_gaze/demo/ext/HRNet-Facial-Landmark-Detection/hrnetv2_pretrained/

# %%
# !cp /content/Drive/MyDrive/a.py /content/few_shot_gaze/demo/

# %%
# %cd /content/few_shot_gaze/demo/
# Out:
# /content/few_shot_gaze/demo

# %%
# !wget -N https://ait.ethz.ch/projects/2019/faze/downloads/outputs_of_full_train_test_and_plot.zip
# Out:
# --2021-07-31 16:56:15--  https://ait.ethz.ch/projects/2019/faze/downloads/outputs_of_full_train_test_and_plot.zip
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1250559857 (1.2G) [application/zip]
# Saving to: ‘outputs_of_full_train_test_and_plot.zip’
#
# outputs_of_full_tra 100%[===================>]   1.16G  19.6MB/s    in 68s
#
# 2021-07-31 16:57:24 (17.6 MB/s) - ‘outputs_of_full_train_test_and_plot.zip’ saved [1250559857/1250559857]

# %%
# !unzip -o outputs_of_full_train_test_and_plot.zip
# Out:
# Archive:  outputs_of_full_train_test_and_plot.zip
#    creating: outputs_of_full_train_test_and_plot/
#   inflating: outputs_of_full_train_test_and_plot/Zg_OLR1e-03_IN5_ILR1e-05_Net64 MAML GazeCapture (test).pdf
#   inflating: outputs_of_full_train_test_and_plot/Zg_OLR1e-03_IN5_ILR1e-05_Net64 MAML MPIIGaze.txt
#   inflating: outputs_of_full_train_test_and_plot/events.out.tfevents.1577856109.984119
#   inflating: outputs_of_full_train_test_and_plot/gc_train_predictions.h5
#   inflating: outputs_of_full_train_test_and_plot/gc_val_predictions.h5
#   inflating: outputs_of_full_train_test_and_plot/gc_test_predictions.h5
#   inflating: outputs_of_full_train_test_and_plot/events.out.tfevents.1577856107.984119
#   inflating: outputs_of_full_train_test_and_plot/Zg_OLR1e-03_IN5_ILR1e-05_Net64 MAML GazeCapture (test).txt
#   inflating: outputs_of_full_train_test_and_plot/Zg_OLR1e-03_IN5_ILR1e-05_Net64 MAML MPIIGaze.pdf
#   inflating: outputs_of_full_train_test_and_plot/mpi_predictions.h5
# ...

# %%
path_original = "/content/MPIIGaze/Data/Original"

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 10.1 MB 9.1 MB/s
# ...
#      |████████████████████████████████| 15.2 MB 185 kB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 239 kB 64.3 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 709 kB 52.0 MB/s
# ...
#      |████████████████████████████████| 246 kB 63.4 MB/s
# ...
#      |████████████████████████████████| 169 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 114 kB 68.1 MB/s
# ...
#      |████████████████████████████████| 251 kB 62.6 MB/s
# ...
#      |████████████████████████████████| 133 kB 56.0 MB/s
# ...
#      |████████████████████████████████| 108 kB 68.3 MB/s
# ...
#      |████████████████████████████████| 546 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 47 kB 5.9 MB/s
# ...
#      |████████████████████████████████| 41 kB 52 kB/s
# ...
#   ERROR: Failed building wheel for scipy
# ...

# %%
# !pip install hdf5storage
# Out:
# ...
#   Using cached hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
# ...

# %%
# !pip install eos-py
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 8.6 MB/s
# ...
#   Created wheel for eos-py: filename=eos_py-1.2.1-cp37-cp37m-linux_x86_64.whl size=399029 sha256=88c44ae58d9063211cf4c6fdae0eb57c831ac128b8e866abcc9d0a43070a0229
#   Stored in directory: /root/.cache/pip/wheels/0c/ac/4d/3284e0d8b8ab97efcd57c3cffd887e91f9446d881d1c3f0d88
# Successfully built eos-py
# ...

# %%
# !wget https://ait.ethz.ch/projects/2019/faze/downloads/demo_weights.zip
# !unzip demo_weights.zip
# Out:
# --2021-07-31 16:59:26--  https://ait.ethz.ch/projects/2019/faze/downloads/demo_weights.zip
# Resolving ait.ethz.ch (ait.ethz.ch)... 129.132.85.38
# Connecting to ait.ethz.ch (ait.ethz.ch)|129.132.85.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25589951 (24M) [application/zip]
# Saving to: ‘demo_weights.zip’
#
# demo_weights.zip    100%[===================>]  24.40M  8.41MB/s    in 2.9s
#
# 2021-07-31 16:59:30 (8.41 MB/s) - ‘demo_weights.zip’ saved [25589951/25589951]
#
# Archive:  demo_weights.zip
#    creating: demo_weights/
#   inflating: demo_weights/weights_ted.pth.tar
#    creating: demo_weights/weights_maml/
#   inflating: demo_weights/weights_maml/256.pth.tar
#   inflating: demo_weights/weights_maml/128.pth.tar
#   inflating: demo_weights/weights_maml/64.pth.tar
#   inflating: demo_weights/weights_maml/32.pth.tar
#   inflating: demo_weights/weights_maml/18.pth.tar
#   inflating: demo_weights/weights_maml/17.pth.tar
# ...

# %%
 # !python3 a.py
# Out:
# mkdir: cannot create directory ‘/content/Processed/’: File exists
# mkdir: cannot create directory ‘/content/Processed/p11/’: File exists
# Processing person  p11
# Processing Person and day p11/day03
# Processing Person and day p11/day06
# Processing Person and day p11/day08
# Processing Person and day p11/day04
# Processing Person and day p11/day19
# Processing Person and day p11/day18
# Processing Person and day p11/day14
# Processing Person and day p11/day12
# Processing Person and day p11/day10
# Processing Person and day p11/day02
# Processing Person and day p11/day15
# Processing Person and day p11/day05
# Processing Person and day p11/day13
# Processing Person and day p11/day01
# Processing Person and day p11/day07
# Processing Person and day p11/day11
# Processing Person and day p11/day17
# Processing Person and day p11/day16
# Processing Person and day p11/day09
# Saved output for person  p11
# mkdir: cannot create directory ‘/content/Processed/p12/’: File exists
# ...
